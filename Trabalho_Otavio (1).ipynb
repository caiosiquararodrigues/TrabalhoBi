# %%
import pandas as pd
import openpyxl
import sqlite3

# %%
df = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx')
df
# Out:
#        ID_mortes DataDiagnostico DataColetaTesteRapido   DataObito  \
# 0         103252      2022-12-17            2022-12-29  2023-01-04
# 1         225679      2022-11-29            2022-12-06  2022-12-21
# 2         499950      2022-08-06            2022-08-11  2022-08-23
# 3         663928      2022-07-05                   NaN  2022-07-18
# 4         812214      2022-07-02            2022-07-02  2022-07-02
# ...          ...             ...                   ...         ...
# 15041    4736272      2020-04-04                   NaN  2020-04-13
# 15042    4736280      2020-04-04                   NaN  2020-04-13
# 15043    4736342      2020-04-02                   NaN  2020-06-11
# 15044    4736674      2020-03-22                   NaN  2020-04-02
# 15045    4736712      2020-03-31                   NaN  2020-04-01
#
#       Classificacao             Evolucao  ID_municipio  ID_FaixaEtaria  \
# 0       Confirmados  Óbito pelo COVID-19             1               1
# ...

# %%
Dim_testerapido = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=1)
Dim_testerapido
# Out:
#          TipoTesteRapido  ID_Testerapido
# 0  Teste rápido Antígeno               1
# 1          Não Informado               2
# 2   Teste rápido IgM/IgG               3
# 3               Ignorado               4

# %%
Dim_resultado = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=2)
Dim_resultado
# Out:
#   ResultadoTesteRapido  ID_Resultado
# 0             Positivo             1
# 1             Negativo             2
# 2        Não Informado             3
# 3         Inconclusivo             4

# %%
Dim_escolariedade = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=3)
Dim_escolariedade
# Out:
#                                          Escolaridade  ID_Escolaridade
# 0   1ª a 4ª série incompleta do EF (antigo primári...                1
# 1   4ª série completa do EF (antigo primário ou 1º...                2
# 2   5ª à 8ª série incompleta do EF (antigo ginásio...                3
# 3                                          Analfabeto                4
# 4                          Educação superior completa                5
# 5                       Educação superior incompleta                 6
# 6   Ensino fundamental completo (antigo ginásio ou...                7
# 7   Ensino médio completo (antigo colegial ou 2º g...                8
# 8   Ensino médio incompleto (antigo colegial ou 2º...                9
# 9                                            Ignorado               10
# 10                                      Não se aplica               11

# %%
Dim_raca = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=4)
Dim_raca
# Out:
#     RacaCor  ID_Raca
# 0   Amarela        1
# 1    Branca        2
# 2  Ignorado        3
# 3  Indigena        4
# 4     Parda        5
# 5     Preta        6

# %%
Dim_faixaetaria = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=5)
Dim_faixaetaria
# Out:
#         FaixaEtaria  ID_FaixaEtaria
# 0   90 anos ou mais               1
# 1      80 a 89 anos               2
# 2      60 a 69 anos               3
# 3      70 a 79 anos               4
# 4      50 a 59 anos               5
# 5      30 a 39 anos               6
# 6      20 a 29 anos               7
# 7      40 a 49 anos               8
# 8      10 a 19 anos               9
# 9        0 a 4 anos              10
# 10      05 a 9 anos              11

# %%
Dim_municipio = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=6)
Dim_municipio
# Out:
#               Municipio  ID_Municipio
# 0        AFONSO CLAUDIO             1
# 1    AGUA DOCE DO NORTE             2
# 2                 AGUAI             3
# 3          AGUIA BRANCA             4
# 4               AIMORES             5
# ..                  ...           ...
# 181               VIANA           182
# 182          VILA PAVAO           183
# 183        VILA VALERIO           184
# 184          VILA VELHA           185
# 185             VITORIA           186
#
# [186 rows x 2 columns]

# %%
Dim_sexo = pd.read_excel('C:/Users/Caio_/.jupyter/mortes.xlsx', sheet_name=7)
Dim_sexo
# Out:
#   Sexo  ID_Sexo
# 0    F        1
# 1    M        2

# %%
conn = sqlite3.connect('mortes')

# %%
df.to_sql(name='fato', con = conn)
# Out:
# 15046

# %%
Dim_testerapido.to_sql(name='Dim_testerapido', con = conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 Dim_testerapido.to_sql(name='Dim_testerapido', con = conn)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# ...

# %%
Dim_resultado.to_sql(name='Dim_resultado', con = conn)
# Out:
# 4

# %%
Dim_escolariedade.to_sql(name='Dim_escolariedade', con = conn)
# Out:
# 11

# %%
Dim_raca.to_sql(name='raca', con = conn)
# Out:
# 6

# %%
Dim_municipio.to_sql(name='Dim_municipio', con = conn)
# Out:
# 186

# %%
Dim_sexo.to_sql(name='Dim_sexo', con = conn)
# Out:
# 2

# %%
pd.read_sql('SELECT * FROM fato', con= conn)
# Out:
#        index  ID_mortes DataDiagnostico DataColetaTesteRapido   DataObito  \
# 0          0     103252      2022-12-17            2022-12-29  2023-01-04
# 1          1     225679      2022-11-29            2022-12-06  2022-12-21
# 2          2     499950      2022-08-06            2022-08-11  2022-08-23
# 3          3     663928      2022-07-05                  None  2022-07-18
# 4          4     812214      2022-07-02            2022-07-02  2022-07-02
# ...      ...        ...             ...                   ...         ...
# 15041  15041    4736272      2020-04-04                  None  2020-04-13
# 15042  15042    4736280      2020-04-04                  None  2020-04-13
# 15043  15043    4736342      2020-04-02                  None  2020-06-11
# 15044  15044    4736674      2020-03-22                  None  2020-04-02
# 15045  15045    4736712      2020-03-31                  None  2020-04-01
#
#       Classificacao             Evolucao  ID_municipio  ID_FaixaEtaria  \
# ...

# %%
# Out:
#   Cell In[63], line 1
#     sqlite3> .table
#              ^
# SyntaxError: invalid syntax
